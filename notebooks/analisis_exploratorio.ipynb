# %%
# 1. Cargar datos y limpiar
import pandas as pd
df = pd.read_csv('../data/Sample-Superstore.csv', encoding='latin1')
df = df.drop_duplicates()

# 2. EDA: Gráficos, estadísticas, correlaciones, etc.

# 3. Diferentes modelos
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
# entrenar ambos y comparar métricas

# 4. Elegir el mejor y guardar en models/
from joblib import dump
dump(mejor_modelo, './models/mejor_modelo.joblib')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      11 # entrenar ambos y comparar métricas
#      12
#      13 # 4. Elegir el mejor y guardar en models/
#      14 from joblib import dump
# ---> 15 dump(mejor_modelo, './models/mejor_modelo.joblib')
#
# NameError: name 'mejor_modelo' is not defined
